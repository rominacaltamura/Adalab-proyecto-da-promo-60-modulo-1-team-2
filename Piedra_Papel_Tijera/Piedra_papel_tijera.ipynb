# %%
import random
lista_opciones=["piedra", "papel", "tijera"]

contadorjugador1=0
contadorjugador2=0

jugador2= random.choice(lista_opciones)



#CONDICIONES A CUMPLIR PARA GANAR

while contadorjugador1 <3 and contadorjugador2 <3:
    
    jugador1= input("Elige piedra, papel o tijera")
    if jugador1 == "piedra":
        
        if  jugador2 == "tijera":
            #gana jugador1
            contadorjugador1 +=1
            print("El jugador 1 ha elegido la opción:" , jugador1)
            print("El jugador 2 ha elegido la opción:" , jugador2)
            print("Ha ganado el jugador 1 esta ronda")
            print("-------------")
            print(f"Jugador 1: {contadorjugador1} - Jugador 2: {contadorjugador2}")
        elif  jugador2 == "papel":
            #gana jugador2
            contadorjugador2 +=1
            print("El jugador 1 ha elegido la opción:" , jugador1)
            print("El jugador 2 ha elegido la opción:" , jugador2)
            print("Ha ganado el jugador 2 esta ronda")
            print("-------------")
            print(f"Jugador 1: {contadorjugador1} - Jugador 2: {contadorjugador2}")
        
        else:
            print("El jugador 1 ha elegido la opción:" , jugador1)
            print("El jugador 2 ha elegido la opción:" , jugador2)
            print("Empate")
            print(f"Jugador 1: {contadorjugador1} - Jugador 2: {contadorjugador2}")

    if jugador1 == "tijera":
        
        if  jugador2 == "papel":
            #gana jugador1
            contadorjugador1 +=1
            print("El jugador 1 ha elegido la opción:" , jugador1)
            print("El jugador 2 ha elegido la opción:" , jugador2)
            print("Ha ganado el jugador 1 esta ronda")
            print("-------------")
            print(f"Jugador 1: {contadorjugador1} - Jugador 2: {contadorjugador2}")
        elif  jugador2 == "piedra":
                #gana jugador2
                contadorjugador2 +=1
                print("El jugador 1 ha elegido la opción:" , jugador1)
                print("El jugador 2 ha elegido la opción:" , jugador2)
                print("Ha ganado el jugador 2 esta ronda")
                print("-------------")
                print(f"Jugador 1: {contadorjugador1} - Jugador 2: {contadorjugador2}")      
        else:
                print("El jugador 1 ha elegido la opción:" , jugador1)
                print("El jugador 2 ha elegido la opción:" , jugador2)
                print("Empate")
                print(f"Jugador 1: {contadorjugador1} - Jugador 2: {contadorjugador2}")
        
    if jugador1 == "papel":
        
        if  jugador2 == "piedra":
            #gana jugador1
            contadorjugador1 +=1
            print("El jugador 1 ha elegido la opción:" , jugador1)
            print("El jugador 2 ha elegido la opción:" , jugador2)
            print("Ha ganado el jugador 1 esta ronda")
            print("-------------")
            print(f"Jugador 1: {contadorjugador1} - Jugador 2: {contadorjugador2}")
        elif  jugador2 == "tijera":
                #gana jugador2
                contadorjugador2 +=1
                print("El jugador 1 ha elegido la opción:" , jugador1)
                print("El jugador 2 ha elegido la opción:" , jugador2)
                print("Ha ganado el jugador 2 esta ronda")
                print("-------------")
                print(f"Jugador 1: {contadorjugador1} - Jugador 2: {contadorjugador2}") 
        else:
            print("El jugador 1 ha elegido la opción:" , jugador1)
            print("El jugador 2 ha elegido la opción:" , jugador2)
            print("Empate")
            print(f"Jugador 1: {contadorjugador1} - Jugador 2: {contadorjugador2}")        

if contadorjugador1>3:
        print:("FIN DEL JUEGO")
        print ("---------")
    
        print(f"Ha ganado el jugador 1")
else:
    print("FIN DEL JUEGO")
    print("---------")
    print(f"Ha ganado el jugador 2")
# Out:
# El jugador 1 ha elegido la opción: piedra
# El jugador 2 ha elegido la opción: piedra
# Empate
# Jugador 1: 0 - Jugador 2: 0
# El jugador 1 ha elegido la opción: piedra
# El jugador 2 ha elegido la opción: piedra
# Empate
# Jugador 1: 0 - Jugador 2: 0
# El jugador 1 ha elegido la opción: piedra
# El jugador 2 ha elegido la opción: piedra
# Empate
# Jugador 1: 0 - Jugador 2: 0
# El jugador 1 ha elegido la opción: piedra
# El jugador 2 ha elegido la opción: piedra
# Empate
# Jugador 1: 0 - Jugador 2: 0
# El jugador 1 ha elegido la opción: papel
# El jugador 2 ha elegido la opción: piedra
# Ha ganado el jugador 1 esta ronda
# -------------
# Jugador 1: 1 - Jugador 2: 0
# El jugador 1 ha elegido la opción: papel
# El jugador 2 ha elegido la opción: piedra
# Ha ganado el jugador 1 esta ronda
# -------------
# Jugador 1: 2 - Jugador 2: 0
# El jugador 1 ha elegido la opción: tijera
# El jugador 2 ha elegido la opción: piedra
# Ha ganado el jugador 2 esta ronda
# -------------
# ...
